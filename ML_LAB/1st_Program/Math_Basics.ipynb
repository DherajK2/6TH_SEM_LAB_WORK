# %%
import math

print(math.sqrt(25))
print(math.factorial(5))
print(math.pi)
print(math.e)
print(math.sin(math.pi/2))
print(math.sin(math.radians(30)))
print(math.pow(2,3))
# Out:
# 5.0
# 120
# 3.141592653589793
# 2.718281828459045
# 1.0
# 0.49999999999999994
# 8.0
